# %%
from torchviz import make_dot
import torch 
from utils.AdaptiveFusionGating.AdaptiveFusionGatingNet import AdaptiveFusionGatingNet
import pickle

# %%
model = AdaptiveFusionGatingNet()
x_t = torch.zeros(1,3,224,224) 
x_v = torch.zeros(1,3,224,224)
out = model(x_t, x_v)

# %%
graph = make_dot(out)
print(graph)
pickle.sys


with open('AFM_graph.pkl', 'wb') as f:
    pickle.dump(graph, f)
# Out:
# digraph {
# 	graph [size="89.25,89.25"]
# 	node [align=left fontsize=12 height=0.2 ranksep=0.1 shape=box style=filled]
# 	2749995537032 [label=SigmoidBackward fillcolor=darkolivegreen1]
# 	2749995537160 -> 2749995537032
# 	2749995537160 [label=AddmmBackward]
# 	2749995537864 -> 2749995537160
# 	2749995537864 [label="
#  (1)" fillcolor=lightblue]
# 	2749995537736 -> 2749995537160
# 	2749995537736 [label=MulBackward0]
# 	2749995538568 -> 2749995537736
# 	2749995538568 [label=ReluBackward0]
# 	2749995538888 -> 2749995538568
# 	2749995538888 [label=AddmmBackward]
# 	2749995538824 -> 2749995538888
# 	2749995538824 [label="
#  (10)" fillcolor=lightblue]
# 	2749995539528 -> 2749995538888
# 	2749995539528 [label=MulBackward0]
# 	2749995539912 -> 2749995539528
# 	2749995539912 [label=ReluBackward0]
# 	2749995540104 -> 2749995539912
# 	2749995540104 [label=AddmmBackward]
# 	2749995540424 -> 2749995540104
# 	2749995540424 [label="
#  (20)" fillcolor=lightblue]
# 	2750064995656 -> 2749995540104
# ...

# %%
from graphviz import Digraph

# %%
dot = Digraph(comment='The Round Table')

# %%
dot
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\envs\multimodal_detection\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     163     try:
# --> 164         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     165     except OSError as e:
#
# ~\Anaconda3\envs\multimodal_detection\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...
